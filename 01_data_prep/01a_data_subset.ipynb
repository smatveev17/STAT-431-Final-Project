# %%
import pandas as pd

# %% [markdown]
# These are the predictors we selected through eda process

# %%
subset_list=['ApprovalFY',
 'DisbursementGross_num',
 'State',
 'UrbanRural_f',
 'SBA_Portion',
 'NAICS_sector',
 'NoEmp',
 'SBA_Appv_num', 'GFC_Period','Bank','PaidInFull']

# %%
train_df=pd.read_csv("../00_data/split_data/train.csv")

# %%
train_df=train_df[subset_list]
train_df
# Out:
#         ApprovalFY  DisbursementGross_num State UrbanRural_f  SBA_Portion  \
# 0             2005                50000.0    NY        Urban         0.50
# 1             2007                65000.0    NY        Urban         0.50
# 2             2007                56245.0    MA        Urban         0.50
# 3             2006                35006.0    VA        Urban         0.50
# 4             2005                20000.0    IL        Urban         0.50
# ...            ...                    ...   ...          ...          ...
# 165132        2006                16600.0    VT        Rural         0.50
# 165133        2008                 5000.0    LA        Urban         0.85
# 165134        2002                25000.0    NY        Urban         0.50
# 165135        2005               119960.0    MA        Rural         0.50
# 165136        2008               128500.0    VA        Urban         0.85
#
#         NAICS_sector  NoEmp  SBA_Appv_num GFC_Period  \
# ...

# %%
train_df_subset=train_df.sample(n=50000, random_state=42)
train_df_subset
# Out:
#         ApprovalFY  DisbursementGross_num State UrbanRural_f  SBA_Portion  \
# 14004         2008               510672.0    FL        Rural     0.500000
# 78435         2007                87569.0    OH        Urban     0.500000
# 107176        2005                30000.0    MD        Urban     0.500000
# 11832         2005                10050.0    PA        Rural     0.500000
# 35043         2008                 6000.0    OH        Urban     0.500000
# ...            ...                    ...   ...          ...          ...
# 146638        2008                25000.0    NY        Urban     0.500000
# 26174         2009               100000.0    MA        Urban     0.500000
# 54258         2004               168300.0    MO        Rural     0.750000
# 127591        1999               172949.0    GA        Urban     0.750001
# 126579        2006                 5000.0    CA        Urban     0.500000
#
#         NAICS_sector  NoEmp  SBA_Appv_num GFC_Period  \
# ...

# %%
train_df_subset.to_csv("../00_data/cleaned_smaller_subsets/train_50k_subset.csv", index=False)
