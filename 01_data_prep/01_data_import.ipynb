# %%
import pandas as pd

# %%
df=pd.read_csv("../00_data/sba_clean_full.csv")
df.head()
# Out:
#    LoanNr_ChkDgt                         Name         City State    Zip  \
# 0     1000146010                       CARVEL         APEX    NC  27502
# 1     1000446006                       SUBWAY  LITTLE ROCK    AR  72223
# 2     1000506000          WEYLAND CORPORATION    CAMARILLO    CA  93010
# 3     1000516003  CHICAGO BRICK UNLIMITED INC        MIAMI    FL  33186
# 4     1000526006                    RZI, INC.  NEW ORLEANS    LA  70130
#
#                              Bank BankState   NAICS ApprovalDate  ApprovalFY  \
# 0           STEARNS BK NATL ASSOC        MN  445299     7-Feb-06        2006
# 1                        HOPE FCU        MS  722211     7-Feb-06        2006
# 2     WELLS FARGO BANK NATL ASSOC        SD  611110     7-Feb-06        2006
# 3                  CITIBANK, N.A.        FL  238140     7-Feb-06        2006
# 4  BUSINESS RES. CAP. SPECIALTY B        LA  532490     7-Feb-06        2006
#
# ...

# %%
df.describe()
# Out:
#        LoanNr_ChkDgt            Zip          NAICS     ApprovalFY  \
# count   3.302770e+05  330277.000000  330277.000000  330277.000000
# mean    3.802474e+09   50717.312165  508569.900611    2005.391480
# std     2.243393e+09   31826.613265  169003.760984       2.516627
# min     1.000146e+09       0.000000  111110.000000    1994.000000
# 25%     2.039015e+09   19946.000000  423910.000000    2004.000000
# 50%     3.049704e+09   48864.000000  513322.000000    2006.000000
# 75%     5.494624e+09   83263.000000  621210.000000    2007.000000
# max     9.984863e+09   99999.000000  928120.000000    2010.000000
#
#                 Term          NoEmp       NewExist      CreateJob  \
# count  330277.000000  330277.000000  330277.000000  330277.000000
# mean       81.421349       7.969456       1.266125       1.955710
# std        57.375510      31.905246       0.441931      14.735029
# min         0.000000       0.000000       1.000000       0.000000
# ...

# %%
len(df.columns)
# Out:
# 42
